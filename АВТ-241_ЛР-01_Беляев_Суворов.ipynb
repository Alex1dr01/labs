# %% [markdown]
# <center>МИНИСТЕРСТВО НАУКИ И ВЫСШЕГО ОБРАЗОВАНИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ </center>
# <center>«НОВОСИБИРСКИЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕТ»</center>
# <center>Кафедра Вычислительной техники </center>
# <br>
# <center> <b> <font size="5">  ОТЧЁТ </font>  </b>  </center>
# <center><font size="3">по лабораторной работе №1</font></center>
# <center><font size="3">по дисциплине: «Системы искусственного интеллекта и машинное обучение» </font></center>
# <br>

# %% [markdown]
# Выполнили студенты гр. АВТ-241:
# - _ _ _ Беляев А.Р _ _ _
# - _ _ _ Суворов А.К _ _ _
#
# Проверил: _ _ _ Осипенко И.В _ _ _
#
# <center>  Новосибирск, 2025  </center>

# %% [markdown]
# # Лабораторная работа #1

# %% [markdown]
# - **Материалы для ЛР расположены в гугл-папке [чтение по ссылке]:
# “СИИиМО-2025.09 Бакалавры”, URL:** [**https://clck.ru/3P2ACM**](https://clck.ru/3P2ACM)
#
# - **Ссылки на вебинар с разбором хода работы ЛР1 и комментариями:**
#   - СИИиМО лекц1 2024-09-05, URL:  https://bbb-records.edu.nstu.ru/playback/presentation/2.3/a4952e329dbbf2cf2ef45258a23905202a5e2d43-1725500067650
#   - СИИиМО лекц2 2024-09-13, URL:  https://bbb-records.edu.nstu.ru/playback/presentation/2.3/e3241f056db43685043a49d16c233932b6ddfae7-1726223685960
#   - СИИиМО лекц3 2024-09-19, URL:  https://bbb-records.edu.nstu.ru/playback/presentation/2.3/54198b7825edaa5a087cf38783a0ecbf8243be2f-1726709646701

# %% [markdown]
# ## Цель работы

# %% [markdown]
# Получить практические навыки работы по решению задачи первичного анализа «сырых» данных, подготовки массива к обработке, выявлению и описанию зависимостей в исходных данных с использованием языка программирования Python.

# %% [markdown]
# ## Ход работы
# Ознакомиться с методическими материалами и примерами выполнения команд.
# Последовательно выполнить следующие шаги применительно к выборке данных, согласно варианту задания:
#
# 1. Работа с данными
#
# 1.1. Ознакомиться вариантом задания
#   - Прочитать содержимое cопровождающего файла `"*.info.txt"`
#       - Определить предметную область
#       - Найти информацию с описанием столбцов таблицы
#   - Осмотреть файл csv в текстовом редакторе и определить:
#       - Символ, используемый для разделения ячеек
#       - Символ, используемый разделения дробной и целой части
#       - Наличие не числовых данных (буквы алфавита)
#       - Наличие штампов даты или времени
#
#   1.2. Получить \*.csv-файл с исходными данными согласно варианту. С помощью текстового редактора определить наличие заголовка и знак-разделитель столбца
#
#   1.3. С помощью библиотеки pandas создать таблицу (объект Dataframe) на основе \*.csv-файла с исходными данными
#
#   1.4. Провести первичный анализ всех данных. Получить размер исходный таблицы
#
#   1.5. Определить наличие пропусков и выбрать способ их обработки. Получить размер таблицы после обработки пропусков
#
#   1.6. Определить наличие и привести нужные для работы признаки к числовому типу
#
#   1.7. Сохранить в виде файла текущее состояние обработанной таблицы (Dataframe)
#
#
# 2. Выбор и обработка признаков
#
#   2.1. Проверить взаимозависимость всех числовых признаков на основе матрицы корреляции
#
#   2.2. Выбрать целевую переменную 'y' и независимые признаки 'x1, x2, x3, ...', оказывающие на нее влияние (целевая - 1 шт., признаки>=2 шт.)
#
#   2.3. Исключить выбросы
#
#   2.4. Сформировать обучающую и проверочную части выборки
#
#
# 3. Построить линейные регрессионные модели для каждой выбранной комбинации признаков :
#   - m1: от ЕДИНСТВЕННОЙ переменной (x1)
#   - m2: от множества НАБОРА#1 переменных (пример: x1, x2, x3)
#   - m3: от множества НАБОРА#2 переменных (пример: x5, x6, x7)
#
# 4. Выполнить анализ полученных моделей:
#
#   4.1. Получить коэффициенты линейной регрессии y(x) = K*x + B
#
#   4.2. Получить оценку точности R2(коэфф. детерминации) и RMSE (среднеквадратичное отклонение)
#
#   4.3. Нанести график прямой y(x) = K*x + B поверх точечной диаграммы (выбранный признак, целевая переменная)
#
#   4.4. Построить диаграмму рассеяния вычисленных значений Y_pred от проверочных значений Y_test
#
#   4.5. Построить гистограмму остатков (разностей между Y_pred и Y_test)
#
# 5. \* В качестве доп. задания предлагается расширить множество формируемых моделей.
#
# 6. Оцените в минутах время затраченное на выполнение основных этапов текущей работы, согласно методологии CRISP.
#
# 7. Собрать итоговую информацию. Сделать обобщающие выводы по выполненной работе (см. требования к содержанию отчёта)

# %% [markdown]
# ## Содержание отчета
# <font color='red'>
#     - Формат отчёта: *.ipynb
# <br>- Название отчета должно быть в формате: АВТ-0xx_ЛР-xx_Фамилия1_Фамилия2
# <br>- Каждый участник бригады отсылает отчёт бригады в своем ЛК Диспейс
# </font>
#
# 1. Результаты первичного анализа исходных данных
#
#         1. Количество записей и признаков
#         2. Смысловое описание признаков
#         3. Типы данных столбцов и информация о пропусках
#         4. Результат замены категориальных или ранговых данных на числовые
#         5. Результат обработки пропущенных значений
#
# 2. Обоснование выбора целевой переменной и признаков для анализа
#
#         1. Перечень вариантов целевых переменных, исходя из п. 1.2.
#         2. Матрица коэффициентов корреляции
#         3. Матрица смежности (графический вариант интерпретации взаимосвязей переменных)
#         4. Информация о целевом значении и признаках на него влияющих
#         5. Результат отчистки выбранных признаков исходного массива от выбросов
#
# 3. Результаты анализа полученных регрессионных линейных моделей (m11,m12,m21,m22)
#
#         1. Уравнение линейной регрессии вида y(x_i, ...) =  K_i*x_i + ... + B
#         2. Оценка точности R2 и RMSE
#         3. График полученной линейной зависимости y(x) = K*x + B поверх точечной диаграммы (y: выбранный признак, x: целевая переменная)
#         4. Построить диаграмму рассеяния вычисленных значений Y_pred от проверочных значений Y_test
#         5. Гистограмму остатков (разностей между Y_pred и Y_test)
#
#
# 4. Оценка временных затрат (в минутах) на выполнение основных этапов текущей работы, согласно методологии CRISP
#
# 5. Выводы по результатам сравнительного анализа полученных регрессионных моделей

# %% [markdown]
# # Работа с данными

# %% [markdown]
# ## Подключение библиотек

# %% [markdown]
# Перед началом работы убедитесь, что необходимые для работы пакеты установлены в системе. Для установки отсутствующих используйте соответствующую команду:
# ```
# > …Путь_к_Python\python -m pip install --upgrade pip
# > …Путь_к_Python\Scripts\pip3  install jupyterlab
# > …Путь_к_Python\Scripts\pip3  install pandas  numpy  scikit-learn
# > …Путь_к_Python\Scripts\pip3  install plotly seaborn matplotlib
# > …Путь_к_Python\Scripts\pip3  install tensorflow  streamlit
# ```
#
# Назначение библиотек:
# * numpy - обработка многомерных массивов, линейная алгебра, преобразование Фурье, случайные числа
# * pandas - обработка (загрузка, сохранение, анализа) данных
# * seaborn - визуализация данных (на базе matplotlib)
# * sklearn - алгоритмы машинного обучения(классификация, регрессия, кластеризация...)
# * scipy - пакет для выполнения научных и инженерных расчётов.

# %%
# Проверка версии и пути к выбранному интерпретатору
import sys
print(f"Версия Python - {sys.version}")
print(f"Путь к интерпретатору Python - {sys.executable}")
# Out:
# Версия Python - 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# Путь к интерпретатору Python - C:\Programs\Python310x64\python.exe

# %%
# Python 3.10
import pandas as pd
import numpy  as np

import sklearn
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score

# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import cm
import seaborn as sns

# %%
# Проверка версий библиотек
for lib in [pd, np, sklearn]:
    print(f"{lib.__name__:<12} {lib.__version__}")
# Out:
# pandas       2.3.3
# numpy        1.26.4
# sklearn      1.7.2

# %% [markdown]
# ## Загрузка входных данных

# %% [markdown]
# Данные "Melbourne Housing Snapshot" содержат информацию о продажах недвижимости в г. Мельбурн (Австралия). Имеющиеся столбцы (признаки объекта)
# - Suburb: название окрестности, пригорода
# - Rooms: Кол-во комнат
# - Price: Цена
# - Method - способ продажи:
#   - S - property sold; SP - property sold prior;
#   - PI - property passed in; PN - sold prior not disclosed;
#   - SN - sold not disclosed; NB - no bid;
#   - VB - vendor bid; W - withdrawn prior to auction;
#   - SA - sold after auction; SS - sold after auction price not disclosed.
#   - N/A - price or highest bid not available.
# - Type - тип недвижимости:
#   - br - bedroom(s);
#   - h - house,cottage,villa, semi,terrace;
#   - u - unit, duplex;
#   - t - townhouse;
#   - dev site - development site;
#   - o res - other residential.
# - SellerG: Агент по недвижимости, совершивший сделку
# - Date: Дата продажи
# - Distance: Расстояние до центрального делового района CBD (central business district)
# - Regionname: Район, название
# - Propertycount: Number of properties that exist in the suburb.
# - Bedroom2 : Кол-во спален
# - Bathroom: Кол-во ванных
# - Car: Кол-во парковочных мест
# - Landsize: Размер участка
# - BuildingArea: Площадь
# - CouncilArea: Управляющая компания

# %% [markdown]
# <b> Путь к файлу вида "./datasets/melbourne_data.csv" подразумевает следующее расположение:
# ```
# WorkDir/
# ├─ datasets/
# │  └─ melbourne_data.csv
# ├─ 1.ЛР-1.ipynb
# ```
# </b>

# %% [markdown]
# Для загрузки табличных данных из файла применятся функция .read_csv() с указанием параметров (путь, кодировка, разделитель, обработка колонок с заголовками или датой...). Обязательным параметроя является путь к файлу, но нам в работе потребуются некоторые дополнительные паратемты.
#
# ```
# pandas.read_csv(
#   filepath_or_buffer,
#   sep       = ','  ,
#   decimal   = '.'  ,
#   header    = 1,
#   na_values = ['?']
# )
# ```
# где используются следующие параметры:
# - filepath_or_buffer: (str) Путь к фалу
# - sep: (str) Символ, используемый для разделения ячеек таблицы  По умолчанию ","
# - decimal: (str) Символ, используемый для разделения дробной и целой части числа. По умолчанию "."
# - header: (int) Номер строки используемой в качестве заголовка (шапки таблицы), нумерация - с нуля.
# - na_value: (str или list) Дополнительные символы для обозначения отсутствующих значений ячеек таблицы

# %%
df = pd.read_csv(
    './datasets/Moscow_Housing_Price_Dataset_nan_24.csv', # путь к файлу через символ "/", (используйте автодополнение)
    sep       = ',' ,
    decimal   = '.' ,
    header    = 0,  # если заголовки в нулевой строке таблицы,
        #  header=None если заголовки отсутствуют
    #na_values =  ['???', ' '], # доп. символы для обозначения отсутствующих значений
)

df[0:2] # отобразить первые строки таблицы df
# Out:
#        Price Apartment type Metro station  Minutes to metro         Region  \
# 0       >??<      Secondary       Опалиха               6.0  Moscow region
# 1  9000000.0      Secondary       Павшино               2.0  Moscow region
#
#    Number of rooms  Area  Living area  Kitchen area  Floor  Number of floors  \
# 0              1.0  30.6         11.1           8.5   25.0                25
# 1              1.0  49.2         20.0          10.0    6.0                15
#
#                   Renovation
# 0                   Cosmetic
# 1  European-style renovation

# %% [markdown]
# Переменная __df__ является экземпляром класса __DataFrame__ библиотеки __pandas__.
#
# "DataFrame" - двумерный массив с изменяемым размером  набором полезных функций, каждый столбец которого является экземпляром класса "Series".
#
# | Series | Series | Series | Series |
# |--------|--------|--------|--------|
# | int | string | float | bool |
# | int | string | float | bool |
# | int | string | float | bool |
#
# Важной особенностью работы с Pandas является то, что все значения столбца Series имеют одинаковый тип данных, т.е. столбец чисел, столбец строк, и  т.д.

# %% [markdown]
# Смысловая интерпретация:
#  - каждая строка - объект, сделка по продаже
#  - каждый столбец - признак, который описывает характеристику объекта(сделки)

# %% [markdown]
# |   | Признак_0 | Признак_1 | Признак_2 |
# |--------|--------|--------|--------|
# | Объект_0 | string | float | bool |
# | Объект_1 | string | float | bool |
# | Объект_2 | string | float | bool |

# %% [markdown]
# Осмотрим полученную таблицу и убедимся, что данные загружены и  корректно разделены на ячейки.

# %%
df [0:3] # Квадратные скобки позволяют получить срез исходной таблицы DataFrame[начало:конец]
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford     85 Turner St      2    h        ???      S  Biggin
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Осмотр данных / Первичный анализ

# %% [markdown]
# ### Размер таблицы

# %% [markdown]
# Атрибут  __DataFrame.shape__ возвращает два значения соответствующей таблице - [кол-во строк, кол-во столбов]

# %%
print  (df.shape)
nrow = df.shape[0]
ncol = df.shape[1]
print ("Итого: " + str(nrow) + " записи, " + str(ncol) + " столбец (признак).")
# Out:
# (22676, 12)
# Итого: 22676 записи, 12 столбец (признак).

# %% [markdown]
# ### Проверка соответствия типов данных для признаков.

# %% [markdown]
# После загрузки файла необходимо проверить, что типы данных каждого столбца (или хотя бы основных) советуют нашим ожиданиям.
#
# Метод `.info()` выводит информацию о текущем типе данных столбцов и количестве "не нулевых значений".
#
# В полученном выводе:
# - int64 / float64 : целочисленные или дробные значения
# - object : значения распознанные как строковые
# - datetime64[ns] : штамп даты и времени

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22676 entries, 0 to 22675
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             22664 non-null  object
#  1   Apartment type    22674 non-null  object
#  2   Metro station     22675 non-null  object
#  3   Minutes to metro  22676 non-null  float64
#  4   Region            22676 non-null  object
#  5   Number of rooms   22675 non-null  float64
#  6   Area              22676 non-null  float64
#  7   Living area       22676 non-null  float64
#  8   Kitchen area      22674 non-null  float64
#  9   Floor             22676 non-null  float64
#  10  Number of floors  22676 non-null  int64
#  11  Renovation        22675 non-null  object
# dtypes: float64(6), int64(1), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# Обратите внимание, что важная для нас переменная "Стоимость квартиры" и "Дата" распознана как строковая, что осложнит или сделает невозможной дальнейшую работу.
#
#     4   Price          13580 non-null  object # должно быть float64
#     7   Date           13580 non-null  object # должно быть datatime64
#
# Рассмотрим столбец "Price". При чтении файла pandas, если в столбце встречается хотя бы одно значение в виде символа или строки, то все значения в столбце будут интерпретированы как строковые. Часто при заполеннии таблиц данных в ячейку с отсвутсвующим значением вносят специальную строку-индикатор. В нашем случае в массиве используется строка с тремя вопросительными знаками `"???"`.
#
# ![изображение.png](data:image/png;base64,...)
#
# При работе с таблицами нам необходимо помечать отсутвующие значения, для этого используется специальное значение NaN (Not a Number).
#
#
# Обозначить недопустимые значения как NaN можно следующими способами:
#
# 1) Указать найденну строку-индикатор в параметре `na_values` функции чтения файла `read_csv`
#
#   ```df = pd.read_csv( ...,  na_values =  ['???'], ...)```
#
# 2) Использовать функцию преобразования библиотеки `pd.to_numeric` с указанием режима замены недопустимых значений на NaN. При этом результат, который вернёт фунция мы можем сохранить в исходный столбец.
# ```
# df['Price'] = pd.to_numeric(
#   df['Price'], # Входной набор значений
#   errors = 'coerce' # режим замены на NaN
# )
# ```

# %%
df['Price'] = pd.to_numeric(
  df['Price'],      # Входной набор значений
  errors = 'coerce' # режим замены на NaN
)

# %% [markdown]
# Осмотрим результат и убедимся, что столбцы являющиеся по смыслу числовыми, в данный момент распознаны pandas корректно.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22676 entries, 0 to 22675
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             22663 non-null  float64
#  1   Apartment type    22674 non-null  object
#  2   Metro station     22675 non-null  object
#  3   Minutes to metro  22676 non-null  float64
#  4   Region            22676 non-null  object
#  5   Number of rooms   22675 non-null  float64
#  6   Area              22676 non-null  float64
#  7   Living area       22676 non-null  float64
#  8   Kitchen area      22674 non-null  float64
#  9   Floor             22676 non-null  float64
#  10  Number of floors  22676 non-null  int64
#  11  Renovation        22675 non-null  object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 2.1+ MB

# %%
df[:3]
# Out:
#         Price Apartment type Metro station  Minutes to metro         Region  \
# 0         NaN      Secondary       Опалиха               6.0  Moscow region
# 1   9000000.0      Secondary       Павшино               2.0  Moscow region
# 2  11090000.0      Secondary      Мякинино              14.0  Moscow region
#
#    Number of rooms  Area  Living area  Kitchen area  Floor  Number of floors  \
# 0              1.0  30.6         11.1           8.5   25.0                25
# 1              1.0  49.2         20.0          10.0    6.0                15
# 2              1.0  44.7         16.2          13.1   10.0                25
#
#                   Renovation
# 0                   Cosmetic
# 1  European-style renovation
# 2                   Cosmetic

# %% [markdown]
# ### Признаки

# %% [markdown]
# Метод __describe()__ выводит основные статистически  данных по каждому числовому признаку (типы int64 и float64):
# * count - число непропущенных значений,
# * mean - среднее арифметическое
# * std - стандартное отклонение (среднеквадратическое),
# * min, max - минимальное и максимальное значение
# * 0.25, 0.50, 0.75 квартили.
# * unique - кол-во уникальных значения
# * top - самое часто встречающееся значение
# * freq - кол-во значений 'top'

# %%
# описание для числовых значений. Оператор ".T" транспонирует матрицу для удобства чтения
df.describe().T
# Out:
#                     count          mean           std        min        25%  \
# Price             22663.0  3.609019e+07  8.271023e+07  1150000.0  7066664.0
# Minutes to metro  22676.0  1.188860e+01  6.204457e+00        0.0        7.0
# Number of rooms   22675.0  2.043131e+00  1.523620e+00        0.0        1.0
# Area              22676.0  7.196683e+01  6.836861e+01        6.0       37.4
# Living area       22676.0  3.851795e+01  3.812428e+01        2.0       17.6
# Kitchen area      22674.0  1.259406e+01  7.728284e+00        1.0        8.6
# Floor             22676.0  9.190466e+00  7.549996e+00        1.0        4.0
# Number of floors  22676.0  1.655609e+01  9.779297e+00        1.0       11.0
#
#                          50%          75%           max
# Price             11343200.0  24753001.50  2.455020e+09
# Minutes to metro        11.0        15.00  6.000000e+01
# Number of rooms          2.0         3.00  1.200000e+01
# Area                    53.3        77.14  1.117000e+03
# Living area             28.5        43.20  5.668000e+02
# Kitchen area            10.6        14.50  1.220000e+02
# Floor                    8.0        13.00  9.200000e+01
# Number of floors        16.0        20.00  9.700000e+01

# %% [markdown]
# Так же в таблица содержит столбцы со строковыми типами данных.

# %%
# описание для НЕ числовых значений, при их наличии
if (df.dtypes == 'object').sum() >0:
    print(df.describe(include=['object', 'bool']).T )
# Out:
#                 count unique                top   freq
# Apartment type  22674      2          Secondary  13151
# Metro station   22675    547  Красногвардейская   2697
# Region          22676      2             Moscow  16113
# Renovation      22675      4           Cosmetic  12788

# %% [markdown]
# ## Изменение названия признаков

# %% [markdown]
# Получим список всех столбцов, при помощи атрибута  __DataFrame.columns__

# %%
df.columns
# Out:
# Index(['Price', 'Apartment type', 'Metro station', 'Minutes to metro',
#        'Region', 'Number of rooms', 'Area', 'Living area', 'Kitchen area',
#        'Floor', 'Number of floors', 'Renovation'],
#       dtype='object')

# %% [markdown]
# В случае, если названия столбцов отсутствуют, либо требуется их изменить, то атрибуту `df.columns` следует присвоить новый список(list) из строк, при этом кол-во строк должно совпадать с кол-вом столбцов.

# %%
colNamesList = ['Price',
                'Apartment type',
                'Metro station',
                'Minutes to metro',
                'Region',
                'Number of rooms',
                'Area',
                'Living area',
                'Kitchen area',
                'Floor',
                'Number of floors',
                'Renovation']

df.columns = (  colNamesList )

# %% [markdown]
# ## Удаление признаков (столбцов)

# %% [markdown]
# В некоторых случаях, при первоначальном осмотре таблицы уже можно заметить столбцы не подходящие для следующией работы, например не информативные или сложные в обработке. Например: столбцы с id базы данных, текстовые описания. Заметить их можно по большому кол-ву уникальных значений в столбце
#
# Внимательно осмотрев вывод `df.describe` вышестоящей ячейки и столбце "unique", составим список признаков для удаления:
# - Suburb: 314 уникальных зн., название пригорода
# - Address: 13378 уникальных зн., адрес недвижимости
# - SellerG: 268 уникальных зн., имя продавца
#
# Для удаления столбцов исползуем функцию `df.drop`, функция по умолчанию не изменяет исходную таблицу, поэтому сохраним полученных результат в туже переменную `df`

# %%
# Удалить столбцы из таблицы можно только один раз
df = df.drop (
    labels = ['Metro station'], # список названий столбцов
    axis=1
    )
df.columns
# Out:
# Index(['Price', 'Apartment type', 'Minutes to metro', 'Region',
#        'Number of rooms', 'Area', 'Living area', 'Kitchen area', 'Floor',
#        'Number of floors', 'Renovation'],
#       dtype='object')

# %%
print ("Итого: " + str(df.shape[0]) + " записи, " + str(df.shape[1]) + " столбец (признак).")
# Out:
# Итого: 22676 записи, 11 столбец (признак).

# %% [markdown]
# ## Пропущенные значения

# %% [markdown]
# Осмотрим значения последних пяти объектов, обратим внимание на значения __NaN__ в столбцах __'BuildingArea'__ и __'CouncilArea'__  - особые значение для заполнения отсутствующих в источнике.

# %%
df[-3:]
# Out:
#            Price Apartment type  Minutes to metro         Region  \
# 22673  3700000.0   New building              30.0  Moscow region
# 22674  5768869.0   New building              14.0  Moscow region
# 22675  6839157.0   New building               8.0  Moscow region
#
#        Number of rooms   Area  Living area  Kitchen area  Floor  \
# 22673              0.0  18.00         15.0           8.1   17.0
# 22674              2.0  36.39         22.0           6.6   12.0
# 22675              2.0  56.13         32.0           5.0   10.0
#
#        Number of floors Renovation
# 22673                17   Cosmetic
# 22674                14   Cosmetic
# 22675                17   Cosmetic

# %% [markdown]
# У объекта DataFrame присутствует функция isna(), которая формирует соответствующую __таблицу-маску__ совпадающую по размеру с исходной, но каждое значение __маски__ - логический индикатор True|False в соостветствии с заданым условием.
# В нашем случае isna() проверяет каждую ячейку таблицы:
# - True  - исходное ячейка не содержала значения или содержала индикатор о пропуске;
# - False - исходное ячейка распознана как корректно заполненная.

# %%
df.isna()[-3:]
# Out:
#        Price  Apartment type  Minutes to metro  Region  Number of rooms  \
# 22673  False           False             False   False            False
# 22674  False           False             False   False            False
# 22675  False           False             False   False            False
#
#         Area  Living area  Kitchen area  Floor  Number of floors  Renovation
# 22673  False        False         False  False             False       False
# 22674  False        False         False  False             False       False
# 22675  False        False         False  False             False       False

# %% [markdown]
# Над таблицей __таблицей-маской__ допустимо выполнить агрегирующую функцию __.sum()__  и т.к. наша таблица состоит из столбцов Series, то будет получена сумма по столбцам, при этом каждое значение TRUE будет приведено к единице. В результате мы получим количество пропущенных элементов по каждому признаку.

# %%
print ( df.isna().sum() ) # используем print для компактного вывода
# Out:
# Price               13
# Apartment type       2
# Minutes to metro     0
# Region               0
# Number of rooms      1
# Area                 0
# Living area          0
# Kitchen area         2
# Floor                0
# Number of floors     0
# Renovation           1
# dtype: int64

# %% [markdown]
# Для понимания как распределены отсутствующие значения в исходной таблице, попробуем получить графическое изображение __таблицы-маски__

# %%
from matplotlib.colors import ListedColormap
def plotTableNA(dataF, addToTilte =""):
    '''  Функция для построения графика отображение отсутсвующих значений'''
    if   len(dataF.columns)> 20:   K = 3
    elif len(dataF.columns)== 1:   K = 1
    else:                          K = 1.7

    figSizeH = 15        # размер полотна, высота
    figSizeW =int(len(dataF.columns)/K) # размер полотна, ширина
    fig, ax = plt.subplots( figsize=(figSizeW, figSizeH)) # создать полотно для рисования, figsize-размер в дюймах

    # отрисовать матрицу значений функцией imshow. Применяется цветовая палитра
    plt.imshow( dataF.isna(),
                cmap = ListedColormap([ '#3B5A92', 'white', ]), # выбор цветовой шкалы, аналог cm.get_cmap('jet'),
                aspect='auto',  # ‘auto’ | ‘equal’ | scalar]    # режим соотнощения сторон
                interpolation= 'none',)                         # отключить размытие
    ax.set_xticks(np.arange(len(dataF.columns)))
    ax.set_xticklabels(dataF.columns, rotation=-70,)
    plt.title("Графическое отображение отсутсвующих значений (белые). "+ addToTilte)
    plt.grid(False) # Сетка
#-------------------------------------
# Вызов функции с указанием параметров
plotTableNA( dataF=df, addToTilte="Исходный" )

# %% [markdown]
# Отсутвующие значения будут препятсвовать дальнейшим расчётам и анализу данных.
#
# Перед дальнейшими действиями следует обработать пропущенные значения. Варианты обработки:
# - Вар.1. заполнить вычисленными значениями, рассчитанными на основе имеющихся значений признака (средние, мин., макс., и т.д.)
# - Вар.2. исключить строки или столбцы:
#   - Вар.2.1. исключить строки, в которых присутствуют пропущенные значения
#   - Вар.2.2. исключить столбцы, в которых присутствуют пропущенные значения
#
# Применяя удаление строк или столбцов, необходимо оставлять максимальной "полезную площадь таблицы" - <ins> ячейки именно тех столбцов, которые представляют интерес для решения задачи.
# </ins>
#
# В некоторых случаях может потребоваться поочерёдно удалять отдельные стролбцы, а только за тем строки.
#
# Функция `.dropna` удалит строки или столбцы с пропусками, в зависимости от выбранного режима. По умолчанию `.dropna` не изменяет изходную таблицу, поэтому мы можем выполнить её для проверки.

# %%
print("Размер исходного DataFrame", df.shape)
print("Вар.3.1. Размер при исключении по строкам",  df.dropna(axis='index', how='any').shape)
print("Вар.3.2. Размер при исключении по столбцам", df.dropna(axis='columns', how='any').shape)
# Out:
# Размер исходного DataFrame (22676, 11)
# Вар.3.1. Размер при исключении по строкам (22657, 11)
# Вар.3.2. Размер при исключении по столбцам (22676, 6)

# %% [markdown]
# Несмотря на существенное кол-во пропущенных значений в признаках "BuildingArea" и "YearBuilt", названные признаки предположительно информативны, поэтому примем решение сохранить эти столбцы, пожетвовав половиной имеющихся данных. Следовательно выбрать режим исключения __"Вар.2.1."__

# %%
# axis='index'   - режим удаление строк, в которых есть пропуски
# axis='columns' - режим удаление столбцов, в которых есть пропуски
df = df.dropna(axis='index', how='any')
print("Размер таблицы после исключения пропусков", df.shape)
# Out:
# Размер таблицы после исключения пропусков (22657, 11)

# %% [markdown]
# Необходимо убедится в том, ожидаемый результат совпадает с фактическим.

# %%
print (df.isna().sum()) # используем print для компактного вывода
# Out:
# Price               0
# Apartment type      0
# Minutes to metro    0
# Region              0
# Number of rooms     0
# Area                0
# Living area         0
# Kitchen area        0
# Floor               0
# Number of floors    0
# Renovation          0
# dtype: int64

# %%
print ("Итого: " + str(df.shape[0]) + " записи, " + str(df.shape[1]) + " столбец (признак).")
# Out:
# Итого: 22657 записи, 11 столбец (признак).

# %% [markdown]
# ## Преобразование к числовыми типу категориальных признаков и даты/времени

# %% [markdown]
# На текущем этапе в таблице присутствуют не числовые столбцы (тип данных object):
# - с категориальными и строковыми значениями
# - строковые значения означающие дату и время
#
# Для использование в анализе данных их необходимо преобразовать к числовым значениям (тип данных int, float) определёнными способами.
#
# Напомню, что под категориальными будем понимать данные имеющие:
# - Ограниченное кол-во уникальных значений
# - Не имеющих численного представления
# - Примеры:
#   - Названия городов, марок или моделей,
#   - Название типов объекта или состояния
#
# Также в таблицах могут встречаться строковые значения, которые описывают дискретные состояния некоторой шкалы.
# - Примеры:
#   - Названия дней недели, месяцев
#   - Сравнительные степени прилагательного, как единицы наличия качества

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22657 entries, 1 to 22675
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             22657 non-null  float64
#  1   Apartment type    22657 non-null  object
#  2   Minutes to metro  22657 non-null  float64
#  3   Region            22657 non-null  object
#  4   Number of rooms   22657 non-null  float64
#  5   Area              22657 non-null  float64
#  6   Living area       22657 non-null  float64
#  7   Kitchen area      22657 non-null  float64
#  8   Floor             22657 non-null  float64
#  9   Number of floors  22657 non-null  int64
#  10  Renovation        22657 non-null  object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 2.1+ MB

# %% [markdown]
# В нашем случае категориальными признаками являются названия, символьные обозначения типа недвижимости и пр.
#
# Для преобразования числовым значениям только те признаки, количество уникальных значений не превышает 8 (строка unique).

# %%
df.describe(include=['object', 'bool']).T  # описание для не числовых значений
# Out:
#                 count unique        top   freq
# Apartment type  22657      2  Secondary  13135
# Region          22657      2     Moscow  16100
# Renovation      22657      4   Cosmetic  12781

# %% [markdown]
# Рассмотрим ситуацию, когда необходимо работать со штампом даты-времени.
# В текущий состоянии столбец `df['Date']` имеет тип - object, т.е. строковый.

# %%
df['Date'][:2] # получить столбец таблицы. Тип данных результата - object (строковый/смешанный)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Programs\Python310x64\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df['Date'][:2] # получить столбец таблицы. Тип данных результата - object (строковый/смешанный)
#
# File C:\Programs\Python310x64\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File C:\Programs\Python310x64\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %% [markdown]
# Используем функцию `pd.to_datetime` для разбора строки на составляющие и создания объекта `datetime64[ns]`, позволяющего удобно работать с сотавными частами даты. При вызове функции необходимо передать парпамерт `format` в виде строки-шаблона в котором будет указано очерёдность элементов даты и знаки разлелители. В строке-шаблоне используются следующие спец. символы:
# - `%Y` - год
# - `%m` - номер месяца
# - `%d` - номер дня
# - `%H` - часы
# - `%M` - минуты
#
# Обратите внимание на тип данных `datetime64[ns]` новой таблицы.
# Полученный результат сохраним в тот же столбец `df['Date']` исходной таблицы.

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html
# Передать зачения столбца в функцию преобразования к типу Дата/время.

df['Date'] = pd.to_datetime(
    df['Date'],  # столбец с строковым представлением даты-времени
    format='%d/%m/%Y' # ожидаемый формат для чтения данных
)
df['Date'][:2]
# Out:
# 1   2016-02-04
# 2   2017-03-04
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# Теперь становится возможно получить отдельный составной элемент даты в виде целого числа.

# %%
# df['Date'].dt.hour        # номер дня недели
# df['Date'].dt.day_of_week # номер дня недели
# df['Date'].dt.day         # номер дня в месяце
# df['Date'].dt.month       # номер месяца в году
# df['Date'].dt.isocalendar().week # номер недели в году
# df['Date'].dt.year        # год

# %% [markdown]
# Для использования информации о дате и времени в следующих шагах анализа, необходимо выбрать и записать нужные элементы даты в таблице в виде новых столбцов.

# %%
df['Date_dayofweek']  = df['Date'].dt.dayofweek # номер дня недели
df['Date_day']        = df['Date'].dt.day    # номер месяца в году
df['Date_month']      = df['Date'].dt.month    # номер месяца в году
df[ ['Date', 'Date_month', 'Date_dayofweek'] ] [:2]
# Out:
#         Date  Date_month  Date_dayofweek
# 1 2016-02-04           2               3
# 2 2017-03-04           3               5

# %% [markdown]
# ### Замена значений (mapping)

# %% [markdown]
# Воможно у вас таблице потребуется заменить значения в столбце по определённым правилам. Этот приём подоёдет
# - для замены на числовые значений строковых, которые описывают дискретные состояния некоторой шкалы.
# - для предварительной замены одних строковых значений дргугими, для их объедитения в более общие категории (уменьшить кол-во уникальных)
#
# Примеры:
# - Дни недели (расположение на шкале):
#       - "Понедельник" => 1
#       - "Вторник"     => 2
#       ...
#       - "Воскресенье" => 7
#
# - Погода (укрупнение категорий):
#       - "Дождь"  => "Осадки"      = 1
#       - "Снег"   => "Осадки"      = 1
#       - "Ясно"   => "Нет_осадков" = 0
#       - "Ветер"  => "Нет_осадков" = 0
#
# Первым шагом получим в виде списка все уникальные значения выбранного признака.

# %%
df["Region"].nunique() # получить количество уникальных значений в столбце Apartment type
# Out:
# 2

# %%
df["Apartment type"].nunique() # получить количество уникальных значений в столбце Apartment type
# Out:
# 2

# %%
df['Region'].unique() # получить массив уникальных значений в столбце Region
# Out:
# array(['Moscow region', 'Moscow'], dtype=object)

# %%
df['Apartment type'].unique() # получить массив уникальных значений в столбце Apartment type
# Out:
# array(['Secondary', 'New building'], dtype=object)

# %% [markdown]
# Следующим шагом используем функцию `.map`, в качестве параметра передадим словарь соответсвий (пары ключ=значение).
#
# Необходимо указать соответствия для ВСЕХ уникальных значений, иначе значения, для которых не будет указано правило заменятся на NaN.

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.Series.map.html
# применить карту соотвествий имеющихся и новых значений. Тип данных результата - int, т.к. замена на числа
df['Region_Digit'] = df['Region'].map(
  {
    'Moscow region'  : 0,
    'Moscow' : 1
  }
)
df[[ 'Region' , 'Region_Digit']] [:2]
# Out:
#           Region  Region_Digit
# 1  Moscow region             0
# 2  Moscow region             0

# %% [markdown]
# ### One-Hot encoding

# %% [markdown]
# Выберем признаки исходной таблицы, которые могут оказывать влияние на стоимость квартиры:
# - имеющие более 2 уникальных значений
# - не имеющие числового пердставления (нельзя однозначно расположить на числовой оси)
#
# Выберем:
# - 'Type' : Тип недвижимости, 3 уникальных
# - 'Regionname' : Название региона, 8 уникальных

# %% [markdown]
# Используем приём известный как One-Hot encoding: cформируем новую таблицу (DataFrame), в которой будут добавлены столбцы по количеству уникальных значений категориального признака.
#
# При этом только в каждой строке новой группы столбцов-индикаторов будет присутствовать  одно значение "1" как признак принадлежности к исходной категории, остальные значения равны "0".
#
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# Метод __pd.get_dummies__ выполняет операцию известную как One-Hot encoding.
#
# В качестве параметров метода передадим:
# - data   : таблица данных, которая содержит только выбранные признаки
# - prefix : приставка к названию столбцов-индикаторов новой таблицы
# - dtype  : тип данных новой таблицы (целые числа или булевы)

# %%
objColNames    = ['Renovation'] # названия признаков в исходной таблицы в виде списка
prefixColNames = ['ren']       # сокращенные названия признаков для новой таблицы в виде списка

df_dummies = pd.get_dummies(
    data   = df[objColNames],  # таблица с признаками для кодирования
    prefix = prefixColNames,   # сокращенные приставки к новым столбцам
    dtype  = int,              # результат сравнения в виде целых чисел {0,1}
)

df_dummies[:3] # осмотрим перые строки новой таблицы
# Out:
#    ren_Cosmetic  ren_Designer  ren_European-style renovation  \
# 1             0             0                              1
# 2             1             0                              0
# 3             0             0                              1
#
#    ren_Without renovation
# 1                       0
# 2                       0
# 3                       0

# %% [markdown]
# ## Формирование таблицы с строго числовыми значениями

# %% [markdown]
# Для выполнения следующих частей работы необходимо выбрать только те столбцы, которые представлены в числовом типе данных.
#
#
# Выберем их исходной таблицы нужные столбцы по их названиям и сохрании результ в новую таблицу `df_digital`.

# %%
# список названий числовых признаков исходной таблицы
digitColName = [
    'Price',
    'Minutes to metro',
    'Number of rooms',
    'Area',
    'Living area',
    'Kitchen area',
    'Floor',
    'Number of floors']

df_digital = df [digitColName]
df_digital
# Out:
#             Price  Minutes to metro  Number of rooms   Area  Living area  \
# 1       9000000.0               2.0              1.0  49.20         20.0
# 2      11090000.0              14.0              1.0  44.70         16.2
# 3       8300000.0               8.0              1.0  35.10         16.0
# 4       6450000.0               6.0              1.0  37.70         15.2
# 5       7150000.0               6.0              1.0  38.40         18.0
# ...           ...               ...              ...    ...          ...
# 22671   4768792.0               8.0              0.0  31.75         13.0
# 22672   5900000.0              25.0              1.0  31.60         10.1
# 22673   3700000.0              30.0              0.0  18.00         15.0
# 22674   5768869.0              14.0              2.0  36.39         22.0
# 22675   6839157.0               8.0              2.0  56.13         32.0
#
#        Kitchen area  Floor  Number of floors
# 1              10.0    6.0                15
# 2              13.1   10.0                25
# 3              11.0   12.0                33
# 4               4.0    5.0                 5
# 5               8.0    8.0                18
# ...             ...    ...               ...
# 22671           5.0    4.0                17
# 22672          12.2   11.0                15
# 22673           8.1   17.0                17
# 22674           6.6   12.0                14
# 22675           5.0   10.0                17
#
# [22657 rows x 8 columns]

# %% [markdown]
# Полученную ранее таблицу `df_dummies` объединим с `df_digital`
#
# Для этого используем метод `pd.concat()`

# %%
# объединить выбранные столбцы из исходной таблицы df  с  столбцами созданной таблицы df_dummies
df_digPlus  = pd.concat(
                        [
                          df_digital,
                          df_dummies
                        ], # список объединяемых объектов

                        axis='columns' # способ объединения - по столбцам
)
df_digPlus[:3]
# Out:
#         Price  Minutes to metro  Number of rooms  Area  Living area  \
# 1   9000000.0               2.0              1.0  49.2         20.0
# 2  11090000.0              14.0              1.0  44.7         16.2
# 3   8300000.0               8.0              1.0  35.1         16.0
#
#    Kitchen area  Floor  Number of floors  ren_Cosmetic  ren_Designer  \
# 1          10.0    6.0                15             0             0
# 2          13.1   10.0                25             1             0
# 3          11.0   12.0                33             0             0
#
#    ren_European-style renovation  ren_Without renovation
# 1                              1                       0
# 2                              0                       0
# 3                              1                       0

# %% [markdown]
# # Выбор целевого значения и признаков для анализа данных

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlus </b></font>

# %% [markdown]
# ## Корреляция

# %% [markdown]
# * __Коэффициент корреляции r-Пирсона__
#
#   Мера линейной взаимосвязи переменных, при нелинейной взаимосвязи непоказателен. Не устойчив к выбросам в выборке. Учитывает числовые значения. Переменные должны иметь нормальное распределение. Изменяется в пределах от -1 до +1.
#
# ![Drag Racing](https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Correlation_examples.png/400px-Correlation_examples.png)

# %% [markdown]
# Построим матрицу корреляции - матрицу значений коэфф. корреляции Пирсона для возможных комбинай пар.

# %%
corr_df = df_digPlus.corr(method='pearson')
corr_df
# Out:
#                                   Price  Minutes to metro  Number of rooms  \
# Price                          1.000000         -0.105124         0.490770
# Minutes to metro              -0.105124          1.000000        -0.082606
# Number of rooms                0.490770         -0.082606         1.000000
# Area                           0.794667         -0.095068         0.686948
# Living area                    0.710826         -0.085913         0.657703
# Kitchen area                   0.583003         -0.062402         0.476331
# Floor                          0.019423          0.016836         0.087552
# Number of floors              -0.021855         -0.031760         0.074248
# ren_Cosmetic                  -0.363839          0.024434        -0.283553
# ren_Designer                   0.374314         -0.054066         0.262173
# ren_European-style renovation -0.008342         -0.018288         0.054481
# ren_Without renovation         0.161805          0.037331         0.090415
#
#                                    Area  Living area  Kitchen area     Floor  \
# Price                          0.794667     0.710826      0.583003  0.019423
# Minutes to metro              -0.095068    -0.085913     -0.062402  0.016836
# Number of rooms                0.686948     0.657703      0.476331  0.087552
# Area                           1.000000     0.906837      0.731818  0.083400
# Living area                    0.906837     1.000000      0.610045  0.072194
# Kitchen area                   0.731818     0.610045      1.000000  0.133745
# Floor                          0.083400     0.072194      0.133745  1.000000
# Number of floors               0.044581     0.036720      0.108237  0.596743
# ren_Cosmetic                  -0.386959    -0.369448     -0.312888 -0.022320
# ren_Designer                   0.353856     0.327888      0.280193  0.054215
# ren_European-style renovation  0.008840     0.021641     -0.003995 -0.071837
# ren_Without renovation         0.196550     0.183407      0.176509  0.054889
#
#                                Number of floors  ren_Cosmetic  ren_Designer  \
# Price                                 -0.021855     -0.363839      0.374314
# Minutes to metro                      -0.031760      0.024434     -0.054066
# Number of rooms                        0.074248     -0.283553      0.262173
# Area                                   0.044581     -0.386959      0.353856
# Living area                            0.036720     -0.369448      0.327888
# Kitchen area                           0.108237     -0.312888      0.280193
# Floor                                  0.596743     -0.022320      0.054215
# Number of floors                       1.000000     -0.131053      0.081021
# ren_Cosmetic                          -0.131053      1.000000     -0.445956
# ren_Designer                           0.081021     -0.445956      1.000000
# ren_European-style renovation         -0.003731     -0.499739     -0.172207
# ren_Without renovation                 0.111595     -0.460761     -0.158775
#
#                                ren_European-style renovation  \
# Price                                              -0.008342
# Minutes to metro                                   -0.018288
# Number of rooms                                     0.054481
# Area                                                0.008840
# Living area                                         0.021641
# Kitchen area                                       -0.003995
# Floor                                              -0.071837
# Number of floors                                   -0.003731
# ren_Cosmetic                                       -0.499739
# ren_Designer                                       -0.172207
# ren_European-style renovation                       1.000000
# ren_Without renovation                             -0.177924
#
#                                ren_Without renovation
# Price                                        0.161805
# Minutes to metro                             0.037331
# Number of rooms                              0.090415
# Area                                         0.196550
# Living area                                  0.183407
# Kitchen area                                 0.176509
# Floor                                        0.054889
# Number of floors                             0.111595
# ren_Cosmetic                                -0.460761
# ren_Designer                                -0.158775
# ren_European-style renovation               -0.177924
# ren_Without renovation                       1.000000

# %% [markdown]
# Для того, чтобы визуально оценить величину коэффициентов корреляции, постоим тепловую карту по значениям взаимозависимости признаков выборки.

# %%
import matplotlib.pyplot as plt
sns.set(style="white")# цвет фона

# построить "маску" для отображения только половины корреляционной матрицы
mask = np.zeros_like(corr_df, dtype=np.bool_)
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(12,12))
sns.set(font_scale=0.8) # размер шрифта

# Построить тепловую карту
sns.heatmap(
            ##################
            data=corr_df,   ### <<<- объект-матрица корреляции
            ##################
            vmin=-1, vmax=1, center=0,
            annot=True,
            cmap = 'RdBu_r',
            mask=mask,   # применить маску
            square=True, # форма ячейки - квадрат
            linewidths=1.0, # зазор между ячейки
            cbar_kws={"shrink": .7}  # уменьшить размер легенды
           )
plt.title(u'Матрица корреляции признаков');

# %% [markdown]
# Получим столбец для целевого признака.

# %%
corr_df["Price"]
# Out:
# Price                            1.000000
# Minutes to metro                -0.105124
# Number of rooms                  0.490770
# Area                             0.794667
# Living area                      0.710826
# Kitchen area                     0.583003
# Floor                            0.019423
# Number of floors                -0.021855
# ren_Cosmetic                    -0.363839
# ren_Designer                     0.374314
# ren_European-style renovation   -0.008342
# ren_Without renovation           0.161805
# Name: Price, dtype: float64

# %% [markdown]
# Для удобства восприятия получим абсолютные величины и отсортируем их.

# %%
# Последовательное применение операции:
# - получить единственный столбец,
# - получить абсолютные значения,
# - отсортировать
corr_df[['Price']].abs().sort_values(by="Price")
# Out:
#                                   Price
# ren_European-style renovation  0.008342
# Floor                          0.019423
# Number of floors               0.021855
# Minutes to metro               0.105124
# ren_Without renovation         0.161805
# ren_Cosmetic                   0.363839
# ren_Designer                   0.374314
# Number of rooms                0.490770
# Kitchen area                   0.583003
# Living area                    0.710826
# Area                           0.794667
# Price                          1.000000

# %% [markdown]
# В качестве целевой переменной выберем признак:
# - **'Price'** - Стоимость.
#
#
# В качестве независимых переменных выберем признаки с высоким абс. значением коэфф. корреляции, но при этом как можно более не связанные  между собой. Кандидаты:
#   * **'YearBuilt'** - Год постройки
#   * **'Landsize'**-  Размер участка
#   * **'Rooms'** - Кол-во комнат
#   * **'BuildingArea'** - Площадь
#   * **'Type_h'** - Тип недвижимости h - house,cottage,villa, semi,terrace;
#   * **'RegN_Southern Metropolitan'** - Район

# %% [markdown]
# Составим списко исходный и целевой переменных

# %%
features = ['ren_Designer',  'Number of floors', 'Area' ]
target   = ['Price']

# %% [markdown]
# # Просмотр характеристик выбранных признаков

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlus </b></font>

# %%
# График признаков попарно
plt.figure(figsize=(7,7))
# %config InlineBackend.figure_format = 'png' # формат изображений PNG, для сокращения времени отрисовки графиков

sns.pairplot(
    df_digPlus[features + target],
    #hue = 'Type',         # Признак разделения
    kind="scatter",        # Тип даграмм: reg,scatter
    diag_kind = 'hist',     # Тип диагоральных даграмм: hist, kde
    plot_kws={'alpha':0.3} # прозрачность точек
);

# %% [markdown]
# ## Поиск и обработка выбросов

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlus </b></font>

# %% [markdown]
# Судя по виду графиков рассеяния в "пустых областях" присутствуют малое кол-во объектов, т.е. в выборе присутствуют аномально малые или большие значения - "выбросы". Для их фильтрации выберем граничные значения с помощью диаграмм размаха (boxplot). Граничными значениями выберем значения соответсующие тонким краям ("усам") - границами статистически значимой выборки.

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
# Цикл: для каждого элемента в объединенном списке
for feature_name in (features+target):

    # Построить полотно для рисования с указанным размером
    plt.figure(figsize=(16,2))

    # На созданном полотне отрисовать boxplot
    sns.boxplot( data=df_digPlus[[feature_name]], # данные
                 orient='h' # ориентация графика
               )

# %% [markdown]
# Установим границы значений, для тех объектов таблицы, которые должны остаться

# %%
# создадим "словарь"/"хэш-таблицу" для удобного обращения, где ключ - это название признака
tressholdDict = {
    'ren_Designer'     : (0, 1)            , # кол-во комнат
    'Number of floors' : (0, 35)     , # год постройки
    'Area'  : (0, 228)        , # размер участка
    'Price'     : (0, 2 * 10**8) , # цена
}

print (tressholdDict)
# Out:
# {'ren_Designer': (0, 1), 'Number of floors': (0, 35), 'Area': (0, 228), 'Price': (0, 200000000)}

# %% [markdown]
# Проверим, какая часть данных выходит за пределы границ значений

# %%
# Цикл: для каждого элемента в словаре/хэш-таблице пройтись по ключам - названиям признаков
for feature_name  in tressholdDict:
    threesMin =  tressholdDict[feature_name][0] # извлечь нижнее пороговое
    tresshMax =  tressholdDict[feature_name][1] # извлечь верхнее пороговое

    # Получить кол-во эл. вне пороговых значений. Прием - фильтрация
    over_count = len(  df_digPlus[
                            ~((df_digPlus[feature_name] >= threesMin ) & (df_digPlus[feature_name] <= tresshMax)) # фильтр по двум границам. ~ инверсия логических значений
                          ]
                    )

    dcount = df_digPlus[feature_name].count() # кол-во эл. общее

    print ('''{}. Принимаем пороговые значение равными {}.
  Кол-во эл. вне пороговых - {} из {} значение(ий) ({:.1%})\n'''.format(
        feature_name,
        tressholdDict[feature_name],
        over_count,
        dcount,
        over_count/ dcount,
    ))
# Out:
# ren_Designer. Принимаем пороговые значение равными (0, 1).
#   Кол-во эл. вне пороговых - 0 из 22657 значение(ий) (0.0%)
#
# Number of floors. Принимаем пороговые значение равными (0, 35).
#   Кол-во эл. вне пороговых - 995 из 22657 значение(ий) (4.4%)
#
# Area. Принимаем пороговые значение равными (0, 228).
#   Кол-во эл. вне пороговых - 803 из 22657 значение(ий) (3.5%)
#
# Price. Принимаем пороговые значение равными (0, 200000000).
#   Кол-во эл. вне пороговых - 826 из 22657 значение(ий) (3.6%)

# %% [markdown]
# Отфильтруем значения которые находятся вне пороговых.

# %%
# Во избежание путаницы создадим для полседующих операций копию исходного объетка
df_digPlusFiltred = df_digPlus.copy()

for feature_name  in tressholdDict:
    threesMin =  tressholdDict[feature_name][0]
    tresshMax =  tressholdDict[feature_name][1]


    # фильтр по двум границам. Оператор "~" -инверсия логических значений
    df_digPlusFiltred = df_digPlusFiltred[
        (df_digPlusFiltred[feature_name] >= threesMin ) & (df_digPlusFiltred[feature_name] <= tresshMax)
        ]
    print("Обработан ", feature_name )


print ("Отброшено {} строк. Осталось {} строк.".format(
    len(df_digPlus)  - len(df_digPlusFiltred),
    len(df_digPlusFiltred))
)
# Out:
# Обработан  ren_Designer
# Обработан  Number of floors
# Обработан  Area
# Обработан  Price
# Отброшено 2042 строк. Осталось 20615 строк.

# %%
# Строим гистограммы по каждому признаку:
# data[features].hist() #Упрощенный вывод графиков

plt.figure(figsize=(16, 5))
plot_number = 0

for feature_name in (features+target):
    plot_number += 1

    plt.subplot(1, len(features+target), plot_number)

    plt.hist(df_digPlusFiltred[feature_name]) # Построение гистрограммы

    plt.title(feature_name)
    plt.xlabel(u'Значения')
    plt.ylabel(u'Частота')
    print (feature_name,
           df_digPlusFiltred[feature_name].min(),
           df_digPlusFiltred[feature_name].max())
# Out:
# ren_Designer 0 1
# Number of floors 1 35
# Area 6.0 228.0
# Price 1150000.0 200000000.0

# %% [markdown]
# ## Сохранение данных

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlusFiltred </b></font>

# %%
df_digPlusFiltred.to_csv(
            './datasets/table_PREPARED.csv', # путь для сохранения
            index=False, # запрет сохранения "индексов" (тек. номеров строк)
           )

# %% [markdown]
# ## Формирование тренировочной и проверочной выборок

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlusFiltred </b></font>

# %% [markdown]
# Для обучения и проверки качества модели применяют прием заключающийся в разделении исходной выборки на части:
#
#     - Обучающую (Train) - данные, на которых модель формирует коэффициенты
#     - Проверочную (Test) - данные, которые предъявляют обученной модели для получения и сравнения вычисленных(Predicted) значений.
#
# Для разделения воспользуемся функцией `train_test_split` из пакета sklearn

# %% [markdown]
# ![train-test-split.png](data:image/png;base64,...)

# %%
valid_size = 0.3 # доля тестовой части в выборке
rand_seed = 8 # начальное состояние генератора случ. чисел

x_train, x_test, y_train, y_test =  train_test_split(
    df_digPlusFiltred[features],    # исходные данные X
    df_digPlusFiltred[target],      # исходные данные y

    test_size = valid_size, # доля тестовой части в выборке
    random_state=rand_seed, # начальное состояние генератора случ. чисел
    shuffle=True            # перемешивание
)

# %%
print ("Кол-во элементов: \n  x_train: {}, y_train {} \n  x_test:  {}, y_test  {} \n  total x: {}, total y {} ".format  (
    len(x_train), len(y_train),
    len(x_test),  len(y_test),
    len(x_train)+len(x_test), len(y_train)+len(y_test),
))
# Out:
# Кол-во элементов:
#   x_train: 14430, y_train 14430
#   x_test:  6185, y_test  6185
#   total x: 20615, total y 20615

# %% [markdown]
# Проверим содержимое обучающей и проверочной частей

# %%
x_test[:3]
# Out:
#        ren_Designer  Number of floors  Area
# 4605              0                24  39.7
# 12546             0                 5  20.3
# 9465              0                25  72.0

# %%
y_test[:3]
# Out:
#             Price
# 4605   16400000.0
# 12546   7349000.0
# 9465   18700000.0

# %% [markdown]
# # Построение модели

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицами <b>x_train, x_test, y_train, y_test </b></font>

# %% [markdown]
# Общая последовательность этапов построения и оценки модели машинного обучения приведены на схеме

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ## Одномерная модель от признака 'Area'

# %% [markdown]
# Для получения линейной регрессионной модели созданим экземпляр класс
# __sklearn.linear_model.LinearRegression()__

# %%
model_Area = linear_model.LinearRegression()

# %% [markdown]
# Полученная модель требует процедуры обучения - подбора значений коэфф. для минимизации отличий между вычисленными значениями и предоставленными целевыми (обучающими y). У большинства моделей доступен метод __.fit(x_train, y_train)__

# %%
# Вычислить коэфф. Ki в функции y(x)=Ki*xi + .... + B
# на тренировочном наборе, т.е. обучить модель
model_Area.fit(
    x_train[['Area']],
    y_train[['Price']]
)
# Out:
# LinearRegression()

# %% [markdown]
# Важным этапом является получение ответов от обученной модели, вычисленных на той части данных, которая не учавствовала в обучении (т.е не учавствовала в подстройке коэфф. мат. модели)

# %%
# Получить вычисленные(predicted) зн. на проверочном наборе
# y_pred = fittedModel.predict(x_test)
y_predicted_on_Area = model_Area.predict(x_test[['Area']])

# %% [markdown]
# Для наглядности построим график рассеяния (он же график разброса, точечный, scatter) зависимой величины y от единственного определяющего признака

# %%
# Создать полотно для рисования с указаными размерами
plt.figure(figsize=(15,5))

# Точечная диаграмма (диаграмма рассеяния) - plt.scatter
plt.scatter(x_train[['Area']],  y_train[['Price']], alpha=0.3, label='Тренировочный') # тренировочный
plt.scatter(x_test[['Area']],   y_test[['Price']],  alpha=0.3, label='Проверочный')   # проверочный

# Нанести график - линии, проведённые через точки - plt.plot
plt.plot( x_test[['Area']], y_predicted_on_Area,
          lw=2, color='red',
          label="y_pred (X) = x0 * {:.3f} + {:.3f}".format(model_Area.coef_[0][0], model_Area.intercept_[0]))
plt.grid(True)  # Сетка. Доп параметры color='black', linewidth=0.7
plt.legend(loc="best")  # Положение легенды
plt.xlabel('Area') # Подпись осей
plt.ylabel(target[0])   # Подпись осей
plt.title(u'График разброса'); # Заголовок

# %% [markdown]
# Т.к. модель является линейной имеются некоторые расхождения между реальными и вычисленными значениями - "ошибки". Для оценки точности построим гистограмму распределения ошибок

# %%
plt.figure(figsize=(6,4))

# Гистограмма и Плотность распределения - sns.distplot
# data = y_true - y_pred
sns.histplot( data = y_test[['Price']] - y_predicted_on_Area,
              color="red",
              kde=True, # оценка плотности в виде кривой
              stat="density",# density: общая площадь равна 1
            )

# Осевая линия
plt.plot(
    [0, 0],
    [0, 10 * pow(10,-8)], '--', lw=2, c='r')

plt.ylabel(u'Плотность')
plt.xlabel(u'Значение ошибки')
plt.title(u'Плотность распределения и гистограмма ошибок');
plt.show()

# %% [markdown]
# Построим еще пару графиков для визуальной оценки качества модели:
# - график рассеяния вычисленных значений Y_pred от проверочных значений Y_test;
# - график квадратов ошибок от проверочных значний Y_test.

# %%
def PLOT34(y_test, y_pred) -> None:
    '''
    Функция построения графиков
    :param y_test: - проверочные значения целевой переменной
    :param y_pred: - вычисленные значения целевой переменной
    '''
    plt.figure(figsize=(12,6))

    # == Диаграмма рассеяния вычисленных значений ==
    # создать первое полотно 121: 1-строк, 2-столбцов, 1-индекс текущего полотна в сетке
    plt.subplot(121)
    plt.scatter(y_test, y_pred,  alpha=0.1, color = "#17becf")
    plt.plot(  [ np.min(y_test), np.max(y_test) ], # x1,x2
               [ np.min(y_test), np.max(y_test) ], # y1,y2
               '--',
               alpha=0.7, lw=3, color = "black")
    plt.title('Диаграмма рассеяния вычисленных значений');
    plt.xlabel('Проверочное Y')
    plt.ylabel('Вычисленное Y')
    plt.grid(True)  # Сетка. Доп параметры color='black', linewidth=0.7

    # == Диаграмма рассеяния ошибок ==
    # создать второе полотно 121: 1-строк, 2-столбцов, 2-индекс текущего полотна в сетке
    plt.subplot(122)
    plt.scatter(y_test, (y_test - y_pred)**2,  alpha=0.1, color = "#17becf")
    plt.title('Диаграмма рассеяния квадрата абсолютной ошибки')
    plt.xlabel('Проверочное Y')
    plt.ylabel('Квадрат абсолютной ошибки')
    plt.grid(True)  # Сетка. Доп параметры color='black', linewidth=0.7
#--------------------------------------------------------------------------

PLOT34(
    y_test = y_test[['Price']],
    y_pred = y_predicted_on_Area
)

# %% [markdown]
# С помощью функций __sklearn.metrics.*__ сравним реальные и вычисленные значениямя и получим важные оценки качества модели

# %%
print ("Линейная одномерная регрессия. Признак 'Area'.")
print ("Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b")
print(f"y = f(X) = ")
for i, kN in enumerate (model_Area.coef_[0]):
    print(f" {' ' if i==0 else '+'}  {kN:.3f} * x{i} ")
print(f"+ {model_Area.intercept_} ")
print("\n")

'''
Вычисление и вывод метрик: MAE, RMSE, R2.
На основе сравнения проверочных и вычисленных.
'''
mae  = metrics.mean_absolute_error(y_test, y_predicted_on_Area)
mse  = metrics.mean_squared_error (y_test, y_predicted_on_Area)
rmse = np.sqrt(mse)
r2   = metrics.r2_score           (y_test, y_predicted_on_Area)
print ("MAE : {:>9,.3f} (средняя абсолютная ошибка)".format( mae ))
print ("MSE : {:>9,.6f} (среднеквадратичная ошибка)".format( mse ))
print ("RMSE: {:>9,.6f} (кв. корень из среднеквадратичной ошибки)".format( rmse ))
print ("R2  : {:>9,.3f} (коэфф. детерминации)".format      ( r2 ))
# Out:
# Линейная одномерная регрессия. Признак 'Area'.
# Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b
# y = f(X) =
#     634784.599 * x0
# + [-16946554.36709136]
#
#
# MAE : 10,929,024.433 (средняя абсолютная ошибка)
# MSE : 307,517,720,524,650.000000 (среднеквадратичная ошибка)
# RMSE: 17,536,183.180061 (кв. корень из среднеквадратичной ошибки)
# R2  :     0.647 (коэфф. детерминации)

# %% [markdown]
# ## Многомерная модель от  НАБОРА#1 переменных (пример: x1, x2, x3, ...)

# %% [markdown]
# Используйте предыдущие решения для построения новой регрессионной модели от  набора из нескольких определяющий переменных (пример: x1, x2, x3, ...)

# %%
# >>>ваш код<<<

model_lin_on_x1x2x3 = linear_model.LinearRegression()

# Вычислить коэфф. на тренировочном наборе, т.е. обучить модель
model_lin_on_x1x2x3.fit(
    x_train[['Area', 'Number of floors', 'ren_Designer']],
    y_train[['Price']]
)

# Получить вычисленные(predicted) зн. на проверочном наборе
y_pred_on_x1x2x3  = model_lin_on_x1x2x3.predict(x_test[['Area', 'Number of floors', 'ren_Designer']])

# %%
plt.figure(figsize=(6,4))

# Гистограмма и Плотность распределения - sns.distplot
# data = y_true - y_pred
sns.histplot( data = y_test[['Price']] - y_pred_on_x1x2x3,
              color="red",
              kde=True, # оценка плотности в виде кривой
              stat="density",# density: общая площадь равна 1
            )

# Осевая линия
plt.plot(
    [0, 0],
    [0, 50 * pow(10,-9)], '--', lw=2, c='r')

plt.ylabel(u'Плотность')
plt.xlabel(u'Значение ошибки')
plt.title(u'Плотность распределения и гистограмма ошибок');
plt.show()

# %%
PLOT34(
    y_test = y_test[['Price']],
    y_pred = y_pred_on_x1x2x3
)

# %%
print ("Линейная многомерная регрессия. Признаки 'Area', 'Number of floors', 'ren_Designer.")
print ("Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b")
print(f"y = f(X) = ")
for i, kN in enumerate (model_lin_on_x1x2x3.coef_[0]):
    print(f" {' ' if i==0 else '+'}  {kN:.3f} * x{i} ")
print(f"+ {model_lin_on_x1x2x3.intercept_[0]:.3f} ")
print("\n")


mae  = metrics.mean_absolute_error(y_test, y_pred_on_x1x2x3)
mse  = metrics.mean_squared_error (y_test, y_pred_on_x1x2x3)
rmse = np.sqrt(mse)
r2   = metrics.r2_score           (y_test, y_pred_on_x1x2x3)
print ("MAE : {:>9,.3f} (средняя абсолютная ошибка)".format( mae ))
print ("MSE : {:>9,.6f} (среднеквадратичная ошибка)".format( mse ))
print ("RMSE: {:>9,.6f} (кв. корень из среднеквадратичной ошибки)".format( rmse ))
print ("R2  : {:>9,.3f} (коэфф. детерминации)".format      ( r2 ))
# Out:
# Линейная многомерная регрессия. Признаки 'Area', 'Number of floors', 'ren_Designer.
# Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b
# y = f(X) =
#     584249.359 * x0
#  +  -330216.207 * x1
#  +  20973100.779 * x2
# + -11016596.360
#
#
# MAE : 10,200,504.247 (средняя абсолютная ошибка)
# MSE : 265,631,775,629,888.531250 (среднеквадратичная ошибка)
# RMSE: 16,298,213.878517 (кв. корень из среднеквадратичной ошибки)
# R2  :     0.695 (коэфф. детерминации)

# %% [markdown]
# ## Многомерная модель от  НАБОРА#2 переменных (пример: x5, x6, x7, ...)

# %% [markdown]
# Используйте предыдущие рещения для построения новой регрессионной модели от другого набора из нескольких определяющий переменных (пример: x5, x6, x7, ...)

# %%
features1 = ['Minutes to metro',  'Floor', 'Living area']
target1   = ['Price']

valid_size = 0.3 # доля тестовой части в выборке
rand_seed = 8 # начальное состояние генератора случ. чисел

x_train, x_test, y_train, y_test =  train_test_split(
    df_digPlusFiltred[features1],    # исходные данные X
    df_digPlusFiltred[target1],      # исходные данные y

    test_size = valid_size, # доля тестовой части в выборке
    random_state=rand_seed, # начальное состояние генератора случ. чисел
    shuffle=True            # перемешивание
)

# %%
model_lin_on_livArea_type_region = linear_model.LinearRegression()

# Вычислить коэфф. на тренировочном наборе, т.е. обучить модель
model_lin_on_livArea_type_region.fit(
    x_train[['Minutes to metro',  'Floor', 'Living area']],
    y_train[['Price']]
)

# Получить вычисленные(predicted) зн. на проверочном наборе
y_pred_on_livArea_type_region  = model_lin_on_livArea_type_region.predict(x_test[['Minutes to metro',  'Floor', 'Living area']])


plt.figure(figsize=(6,4))

# Гистограмма и Плотность распределения - sns.distplot
# data = y_true - y_pred
sns.histplot( data = y_test[['Price']] - y_pred_on_livArea_type_region,
              color="red",
              kde=True, # оценка плотности в виде кривой
              stat="density",# density: общая площадь равна 1
            )

# Осевая линия
plt.plot(
    [0, 0],
    [0, 50 * pow(10,-9)], '--', lw=2, c='r')

plt.ylabel(u'Плотность')
plt.xlabel(u'Значение ошибки')
plt.title(u'Плотность распределения и гистограмма ошибок');
plt.show()
print ("Линейная многомерная регрессия. Признаки 'Living area', 'Apartment_type_Digit',  'Region_Digit'.")
print ("Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b")
print(f"y = f(X) = ")
for i, kN in enumerate (model_lin_on_livArea_type_region.coef_[0]):
    print(f" {' ' if i==0 else '+'}  {kN:.3f} * x{i} ")
print(f"+ {model_lin_on_livArea_type_region.intercept_[0]:.3f} ")
print("\n")

'''
Вычисление и вывод метрик: MAE, RMSE, R2.
На основе сравнения проверочных и вычисленных.
'''
mae  = metrics.mean_absolute_error(y_test, y_pred_on_livArea_type_region)
mse  = metrics.mean_squared_error (y_test, y_pred_on_livArea_type_region)
rmse = np.sqrt(mse)
r2   = metrics.r2_score           (y_test, y_pred_on_livArea_type_region)
print ("MAE : {:>9,.3f} (средняя абсолютная ошибка)".format( mae ))
print ("MSE : {:>9,.6f} (среднеквадратичная ошибка)".format( mse ))
print ("RMSE: {:>9,.6f} (кв. корень из среднеквадратичной ошибки)".format( rmse ))
print ("R2  : {:>9,.3f} (коэфф. детерминации)".format      ( r2 ))
# Out:
# Линейная многомерная регрессия. Признаки 'Living area', 'Apartment_type_Digit',  'Region_Digit'.
# Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b
# y = f(X) =
#     -227878.035 * x0
#  +  -205818.055 * x1
#  +  934699.624 * x2
# + -4913954.123
#
#
# MAE : 11,634,111.109 (средняя абсолютная ошибка)
# MSE : 415,188,161,383,155.937500 (среднеквадратичная ошибка)
# RMSE: 20,376,166.503618 (кв. корень из среднеквадратичной ошибки)
# R2  :     0.523 (коэфф. детерминации)

# %% [markdown]
# # Итоги. Сравнение полученных моделей

# %% [markdown]
# Укажите основные численные значения полученные в вашей работе:
# - Размеры таблиц данных на этапах:
#   - исходная таблица при загрузке csv-файла : Строк x Столбцов
#   - после исключения пропущенных значений : Строк x Столбцов
#   - после исключения выбросов : Строк x Столбцов

# %% [markdown]
# Приведите все численные оценки всех моделей для более удобного сравнения. Пример:
#
#       M1. Линейная одномерная регрессия. Признак 'Area'.
#         Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b
#         y = f(X) = 634784.599 * x0 + [-16946554.36709136]
#         MAE : 10,929,024.433 (средняя абсолютная ошибка)
#         MSE : 307,517,720,524,650.000000 (среднеквадратичная ошибка)
#         RMSE: 17,536,183.180061 (кв. корень из среднеквадратичной ошибки)
#         R2  :     0.647 (коэфф. детерминации)
#
#       M2. Линейная многомерная регрессия. Признаки 'Area', 'Number of floors', 'ren_Designer.
#         Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b
#         y = f(X) = 584249.359 * x0 + -330216.207 * x1 + 20973100.779 * x2 + -11016596.360
#         MAE : 10,200,504.247 (средняя абсолютная ошибка)
#         MSE : 265,631,775,629,888.531250 (среднеквадратичная ошибка)
#         RMSE: 16,298,213.878517 (кв. корень из среднеквадратичной ошибки)
#         R2  :     0.695 (коэфф. детерминации)
#
#       M3 Линейная многомерная регрессия. Признаки 'Living area', 'Apartment_type_Digit',  'Region_Digit'.
#         Формула линейной регресси y(X) = k0*x0 + ... kN*xN + b
#         y = f(X) = -227878.035 * x0 + -205818.055 * x1 + 934699.624 * x2 + -4913954.123
#         MAE : 11,634,111.109 (средняя абсолютная ошибка)
#         MSE : 415,188,161,383,155.937500 (среднеквадратичная ошибка)
#         RMSE: 20,376,166.503618 (кв. корень из среднеквадратичной ошибки)
#         R2  :     0.523 (коэфф. детерминации)

# %% [markdown]
# Оцените в минутах время затраченное на выполнение основных этапов текущей работы, согласно методологии CRISP, затем заполните эту информацию в следующей ячейке для получения столбчатой диаграммы.
#
# ![изображение.png](data:image/png;base64,...)

# %%
# Создадим датафрейм для хранения значений
dfSpendTimeLab1 = pd.DataFrame.from_dict(
{
  "1": {"step": "Бизнес Анализ",                       "duration, min" :  10  },
  "2": {"step": "Анализ данных",                       "duration, min" :  10  },
  "3": {"step": "Подготовка данных",                   "duration, min" :  20  },
  "4": {"step": "Моделирование (Обуч.и подг.)",        "duration, min" :  30  },
  "5": {"step": "Моделирование (Оценка кач. моделей)", "duration, min" :  30  },
  "6": {"step": "Оценка решения + Внедрение",          "duration, min" :  15  },
}
, orient="index"
).sort_index(ascending=False)

# Построить столбчатую диаграмму
fig = plt.figure()
plt.barh(y = dfSpendTimeLab1["step"], width= dfSpendTimeLab1["duration, min"], )
plt.xlabel("Затраченное время, мин")

# Построить круговую диаграмму
fig = plt.figure()
plt.pie(x= dfSpendTimeLab1["duration, min"], labels=dfSpendTimeLab1["step"],  startangle = 90 )

plt.show()

# %% [markdown]
# # Выводы по работе

# %% [markdown]
# ...
#
# Сравните модели между собой по метрике точности R2:
# - какая из полученных моделей имеет макс. значение метрики R2?
# - во сколько раз метрики R2 отличаются между моделями?
# - какие из выбранных признаков X являются необходимыми для увеличения R2?
# - как изменяется метрика R2 при дополнении одниз признаков X другими?

# %%
Модель M2 имеет максимальное значение R² = 0.695. Она использует признаки Area, Number of floors и ren_Designer.

M2 превосходит M1 в 1.074 раза (0.695/0.647 = 1.074), M2 превосходит M3 в 1.329 раза (0.695/0.523 = 1.329), M1 превосходит M3 в 1.237 раза (0.647/0.523 = 1.237).

Необходимы признаки Area (основной предиктор, коррелляция 0.79), Number of floors (независимый от Area, коррелляция 0.045) и 
ren_Designer (категориальный признак, коррелляция 0.26). Эти признаки ортогональны и не создают мультиколлинеарность.

При добавлении Number of floors к Area R² увеличивается примерно на 2.3%, при добавлении ren_Designer происходит дополнительный прирост на 2.8%, итого +4.8%. 
Замена Area на Living area (модель M3) приводит к падению R² на 17.2% из-за высокой коррелляции (0.66) и мультиколлинеарности.
